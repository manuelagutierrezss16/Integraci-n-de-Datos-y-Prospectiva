# %% [markdown]
# <a href="https://colab.research.google.com/github/manuelagutierrezss16/Integraci-n-de-Datos-y-Prospectiva/blob/main/Manuela_Gutierrez_0_Actividad_Introductoria.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTAR LIBRRERIAS
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Buenas tardes profe, no entendi muy bien las instrucciones de la actividad, por esto solo realice lo mismo que en el video teniendo en cuenta lo que me habian enselñado en la clase de analitica de negocios, puse lo que no entiendo (que despues buscare y dado el caso que sea necesario le preguntare) en cada codigo puse mi punto de vista de lo que se y no se para que lo tenga en cuenta ya que entiendo que esto es para verificar mi conocimiento en colab.
#
# Ademas continuando con las rubricas entiendo que debo hacer un informe detallado y critico de mi interaccion con la IA, en un punto le comente que me ayudo de esta para agilizar procesos como la creacion del histograma en donde solo describo lo que quiero y la IA me lo crea asi me queda mucho más facil entender y mejorar los procesos, tambien el uso de esta me preocupa un poco por la informacion que se gener en min y max, ya que nos dan resultados distintos, suponiendo que el .describe es uso de IA y no como tal el escribir el codigo.
#
# Espero esto sea suficiente y sino me gustaria una retroalimentacion para entender su mmodo de califiacr y/o pensar para darle un muy buen resultado en mis proximas entregas, muchas gracias.

# %%
df = pd.read_excel('/0. SolicitantesCrédito(Quiz 1).xlsx')
# Dado que solo hay una hoja y no necesito ver las más de 8 mil filas y
#aun no tengo tan bien entendido como funciona lo de seleccionar hojas voy a ahcerlo
# como me enseñaron, si tiene correcciones o veo que en un futuro lo necesito agradeceria que me explique esta parte.
df.head()
# Out:
#    Unnamed: 0  Edad   Sexo Estado civil  Hijos  Perscargo  Estrato  \
# 0           1    38     NR       Casado      1          0        3
# 1           2    51     NR     Separado      6          1        4
# 2           3    37  Mujer       Casado      2          0        3
# 3           4    29     NR     Separado      1          0        2
# 4           5    42  Mujer       Casado      3          4        2
#
#   Nivel de estudios Tipo de contrato  Ingresos  ...  Plazo    Cuota (COP)  \
# 0         Bachiller          Ninguno   5424576  ...     48   82691.506204
# 1           Técnico          Ninguno   1144064  ...     36   22781.212598
# 2         Tecnólogo       Indefinido   2069853  ...     36   46294.596244
# 3         Tecnólogo          Ninguno   1893080  ...     24   69564.950015
# 4   Especializacion          Ninguno   3000367  ...     24  112478.307883
#
#           ConoCliente          Garantia            RespPat  \
# ...

# %%
df.shape
# Out:
# (8378, 35)

# %%
 Edad = df[['Edad']]
 Edad.head()
 # por alguna razon el colab del video y el mio es distinto y no me enseñarona anteriormente como ver las variables desde el lado
 #izquierdo, encuentro algo llamado inspector de datos, supongo que es lo mismo pero se ve diferente, por esto pongo shape
# Out:
#    Edad
# 0    38
# 1    51
# 2    37
# 3    29
# 4    42

# %%
Edad.info()
# con lo que yo tenia entendido aca con el non null puedo verificar si hay valores nulos o no, en este caso no hay por que dice
# (no nulos) 8378, lo cual es la contidad de filas totales de la tabla, pero de igual forma hago el dropna
Edad = Edad.dropna()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8378 entries, 0 to 8377
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Edad    8378 non-null   int64
# dtypes: int64(1)
# memory usage: 65.6 KB

# %%
Edad.describe()
# No entedi para que es o como tal que es el array, es algo que no me explicaron.
# Tambien me enseñaron a hacer esta tabla para agilizar el procezo e igual veo la media y la desviacion estandar
# Tambien me muestra la edad minima y maxima, pero gracias al video se hacerlo de otra forma,
#AUNQUE ME PREOCUPA QUE DEN RESULTADOS DISTINTOS A LOS DEL VIDEO,¿ CUAL DEVERIA USAR?.
# Out:
#               Edad
# count  8378.000000
# mean     40.913583
# std      12.226560
# min      21.000000
# 25%      31.000000
# 50%      41.000000
# 75%      49.000000
# max      73.000000

# %%
# Realizar un histograma de Edad
# A mi me enseñaron a escribir lo de arriba y usar Tab para que la IA me ayude a redactarlo y hacerlo mas rapido, pero igual lo reviso y lo entiendo
plt.hist(Edad, bins=20)
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.title('Histograma de Edad')
plt.show()

# %%
VP=np.exp(-0.5*((60-np.mean(Edad))/(np.std(Edad)))**2)
print(VP)
# Esto nunca lo había hecho, en ninguna de las clases en las que programe me pidieron hacer una operacion mas alla de una suma o resta
# Out:
# Edad    0.295643
# dtype: float64
# /usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py:3800: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)

# %% [markdown]
# El valor de pertenencia es la fuerza con la que un punto de datos esta asociado a un cluster (segun internet, no tengo el concepto muy presente) 0 es ninguna asociacion y 1 asociacion completa, al ver que la edad de 60 nos da un valor de pertenencia de 0.29 nos indica que casi no tiene asociacion, si buscamos crear un cluster esto nos indicaria que las personas de 60 años no solicitan casi creditos asi que si necesitamos incentivar a mas creditos podriamos iniciar por estas personas o si necesitamos un analisis general podriamos ver que no son tan relevantes como otras edades en la creacion de un grupo a revisar.
